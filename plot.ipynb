# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
x = np.linspace(2020, 2030, 10)
TAM = np.array([8.3, 9.88, 10.5, 14, 15, 17, 19.5, 20, 21, 23 ])
SOM = 0.05*TAM
# plt.plot(x,TAM, label="TAM")
plt.plot(x,SOM, label="SOM")
# plt.title("Expected growth of Serviceable Obtainable Market (SOM)")
plt.xlabel('year')
plt.ylabel('Market value (Billion Euros)')
plt.legend()
plt.savefig('plot_1.png', dpi=300)
